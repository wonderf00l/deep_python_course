# %%
import collections

# %%
def add_numbers(a, b):
    return a + b


def get_some_value(
    some_value_1,
    some_value_2,
    some_value_3,
):
    pass


with (
    open("source_name_file.txt", "r") as src_file_obj,
    open("destination_name_file.txt", "wb") as dest_file_obj
):
    pass


with open(
    "source_name_file.txt", "r"
) as src_file_obj, open(
    "destination_name_file.txt", "wb"
) as dest_file_obj:
    pass

# %%
import sys
import os
from os import local
# import threading
from threading import *  # wrong!

import django
import pylint
from django import filters

# isort

from local_project import function_x


PORT = 5001
SOME_HOST = "locahost"


class TestSome(TestCase):
    def setUp(self):
        pass

    def test_some_value(self):
        pass


class Thread:
    pass


class ThreadPool:
    pass


def get_fn_result(a, b=None):
    if isinstance(a, int):
        raise Exception("wrong!")

    error_message = a + b  # to make faster

    t = Thread(target=x)
    
    fn(1, 4)
    
    lst = []
    lst[:]
    lst[1:-1:2]
    
    if some_cond1 and some_cond2():
        pass

    return z


def fn1():
    pass


class A:
    def __init__(self):
        self.a = 10
    
    def __str__(self):
        return "A10"


if __name__ == "__main__":
    pass

# %%
def fn() -> tuple[int, ...]:
    return 1, 2
